# %% [markdown]
# # **Work With Gemini Ai**
#
# ---

# %%
pip install -q -U google-generativeai

# %% [markdown]
# ### Importing Libraries

# %%
import pathlib
import textwrap
import google.generativeai as genai
# A utility to securely store your API key

from IPython.display import display
from IPython.display import Markdown

# %%
GOOGLE_API_KEY="AIzaSyC8_gwU5LSVQJk3iIXyj5xJ94ArNK11dXU"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
import google.generativeai as genai
GOOGLE_API_KEY="AIzaSyC8_gwU5LSVQJk3iIXyj5xJ94ArNK11dXU"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
prompt = "What is the meaning of life?"
response = model.generate_content(prompt)
specific_answer = response.candidates[0].content.parts[0].text
    
print(specific_answer)
# Out:
# **Philosophical Perspectives on the Meaning of Life:**
#
# * **Existentialism:** Focuses on the individual's freedom and responsibility to create their own meaning in life.
# * **Absurdism:** Suggests that life is inherently meaningless and absurd, and individuals must find ways to cope with this existential reality.
# * **Nihilism:** Holds that life has no intrinsic meaning or purpose.
# * **Hedonism:** Views pleasure and happiness as the highest goods in life.
# * **Eudaimonia:** The classical Greek concept of a life well-lived, centered around virtue, excellence, and the pursuit of fulfillment.
# * **Religion and Spirituality:** Offer a framework for understanding the purpose of life as given by a higher power or divine being.
# * **Scientific Naturalism:** Asserts that life is solely the result of natural processes and has no inherent meaning beyond the survival of the species.
#
# **Personal Perspectives on Meaning:**
#
# * **Purpose-Driven:** A sense of direction and meaning is derived from a specific goal, career, or passion.
# * **Relationship-Centered:** Meaning is found in connections with loved ones, family, and communities.
# * **Experiential:** Meaning is derived from the accumulation of unique and memorable experiences.
# * **Values-Guided:** Actions and choices align with deeply held beliefs and values, providing a sense of purpose and direction.
# * **Growth and Learning:** Meaning is found in the journey of self-improvement, knowledge acquisition, and personal development.
# * **Contribution to Society:** Meaning is derived from making a positive impact on the world, helping others, and contributing to a greater good.
#
# **Cultural and Societal Factors:**
#
# * **Materialism and Consumerism:** Can create a false sense of meaning based on material possessions and social status.
# * **Social Norms and Expectations:** Can influence our perceptions of what constitutes a meaningful life.
# * **Historical Context:** The search for meaning can vary depending on the era, cultural beliefs, and social conditions.
#
# **Ultimately, the meaning of life is a highly personal and subjective question that can evolve throughout one's lifetime. There is no universally accepted answer, and different perspectives can coexist and provide guidance and purpose.**

# %% [markdown]
# # Working image using Gemini Ai

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
import PIL


# Open the image
img = PIL.Image.open('image.jpeg')

# Initialize the GenerativeModel
model = genai.GenerativeModel('gemini-pro-vision')

# Generate content from the image
response = model.generate_content(img)

def bot(text) -> str :
    try:
        # Check if 'candidates' list is not empty
        if response.candidates:
            # Access the first candidate's content if available
            if response.candidates[0].content.parts:
                generated_text = response.candidates[0].content.parts[0].text
                print("Generated Text:", generated_text)
            else:
                print("No generated text found in the candidate.")
        else:
            print("No candidates found in the response.")
    except (AttributeError, IndexError) as e:
        print("Error:", e)


print(bot(response))
# Out:
# Generated Text:  if (me != success) {
#   poverty.get();
# } else {
#   life.great();
#   money.get();
#   live.myDream();
# }
# None

# %%
import PIL
# Initialize the GenerativeModel
model = genai.GenerativeModel('gemini-pro-vision')

# Open the image
img = PIL.Image.open('image.jpeg')

# Generate content from the prompt and image
response = model.generate_content(["What about this image?", img], stream=False)
response.resolve()

def bot(text) -> str:
    try:
        # Check if 'candidates' list is not empty
        if response.candidates:
            # Access the first candidate's content if available
            if response.candidates[0].content.parts:
                generated_text = response.candidates[0].content.parts[0].text
                print("Generated Text:", generated_text)
            else:
                print("No generated text found in the candidate.")
        else:
            print("No candidates found in the response.")
    except (AttributeError, IndexError) as e:
        print("Error:", e)

print(bot(response))
# Out:
# Generated Text:  This is an inspirational image that uses ASCII art to create a motivational message. The message is that if you are not successful, you will live in poverty. However, if you are successful, you will have a great life and be able to live your dreams. The image is written in a programming language, which adds to its appeal for people who are interested in technology.
# None
